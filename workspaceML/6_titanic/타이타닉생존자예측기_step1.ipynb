# %% [markdown]
# # Titanic: Machine Learning from Disaster
#
#
# - 문제 파악
# - 데이타 획득
# - 데이타 분석
# - Feature engineering
# - 모델링
# - 테스팅

# %%
# 주피터 노트북 환경설정
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

from IPython.display import Image

from IPython.core.display import display, HTML
display(HTML("<style>.container { font-weight: bold !important; }</style>"))
display(HTML("<style>.container { width: 98% !important; }</style>"))
# Out:
# <style>.container { font-weight: bold !important; }</style>
# <style>.container { width: 98% !important; }</style>

# %% [markdown]
# ## 1. 문제 파악
#
# 타이타닉호의 생존자를 예측해라

# %%
from IPython.display import Image
Image(url= "https://static1.squarespace.com/static/5006453fe4b09ef2252ba068/5095eabce4b06cb305058603/5095eabce4b02d37bef4c24c/1352002236895/100_anniversary_titanic_sinking_by_esai8mellows-d4xbme8.jpg")
# Out:
# <img src="https://static1.squarespace.com/static/5006453fe4b09ef2252ba068/5095eabce4b06cb305058603/5095eabce4b02d37bef4c24c/1352002236895/100_anniversary_titanic_sinking_by_esai8mellows-d4xbme8.jpg"/>

# %% [markdown]
# ## 2. 데이타 획득
#
# kaggle ( https://www.kaggle.com/c/titanic/data )
#
# ### load train, test dataset using Pandas

# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('input/train.csv')
test = pd.read_csv('input/test.csv')

# %%
train.columns, len(train.columns)
# Out:
# (Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#         'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#        dtype='object'), 12)

# %%
# 'Survived' X
test.columns, len(test.columns)
# Out:
# (Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#         'Ticket', 'Fare', 'Cabin', 'Embarked'],
#        dtype='object'), 11)

# %%
train.shape, test.shape
# Out:
# ((891, 12), (418, 11))

# %% [markdown]
# ## 3. 데이타 분석

# %% [markdown]
# ### Data Dictionary
# - Survived: 	0 = No, 1 = Yes
# - pclass: 	Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd
# - sibsp:	# of siblings / spouses aboard the Titanic
# - parch:	# of parents / children aboard the Titanic
# - ticket:	Ticket number
# - cabin:	Cabin number
# - embarked:	Port of Embarkation	C = Cherbourg, Q = Queenstown, S = Southampton

# %%
test.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# **Total rows and columns**
#
# We can see that there are 891 rows and 12 columns in our training dataset.

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.shape
# Out:
# (891, 12)

# %%
test.shape
# Out:
# (418, 11)

# %%
# Age, Cabin, Embarked 컬럼은 누락값이 있다
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
# Age, Cabin, Fare 컬럼은 누락값이 있다
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
# 누락값의 갯수 확인
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# ### 시각화( visualization )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set() # setting seaborn default for plots

# %% [markdown]
# ### Bar Chart for Categorical Features
# - Pclass
# - Sex
# - SibSp ( # of siblings and spouse)
# - Parch ( # of parents and children)
# - Embarked
# - Cabin

# %% [raw]
# # 컬럼에 따라 막대 그래프를 생성하는 함수 정의
# def bar_chart(feature):
#     survived = train[train['Survived']==1] \
#                     [feature].value_counts()
#     dead = train[train['Survived']==0]  \
#                     [feature].value_counts()
#     df = pd.DataFrame([survived,dead])
#     df.index = ['Survived','Dead']
#     df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
# 컬럼에 따라 막대 그래프를 생성하는 함수 정의 
def bar_chart(feature):
    survived = train[train['Survived']==1][feature].value_counts()
    dead = train[train['Survived']==0][feature].value_counts()
    df = pd.DataFrame([survived,dead])
    df.index = ['Survived','Dead']
    df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
bar_chart('Sex')

# %%
train['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
bar_chart('Pclass')

# %%
train['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
bar_chart('SibSp')

# %%
bar_chart('Parch')

# %%
train['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
bar_chart('Embarked')

# %% [markdown]
# The Chart confirms **a person aboarded from C** slightly more likely survived
# The Chart confirms **a person aboarded from Q** more likely dead
# The Chart confirms **a person aboarded from S** more likely dead

# %% [markdown]
# # 전처리( Feature engineering)

# %%
# train.head()

# %% [markdown]
# ## how titanic sank?
#
# sank from the bow of the ship where third class rooms located
# conclusion, Pclass is key feature for classifier

# %%
Image(url= "https://static1.squarespace.com/static/5006453fe4b09ef2252ba068/t/5090b249e4b047ba54dfd258/1351660113175/TItanic-Survival-Infographic.jpg?format=1500w")
# Out:
# <img src="https://static1.squarespace.com/static/5006453fe4b09ef2252ba068/t/5090b249e4b047ba54dfd258/1351660113175/TItanic-Survival-Infographic.jpg?format=1500w"/>

# %%
# train.head(10)

# %% [markdown]
# ### Name 전처리
#
# - Name 컬럼에서 의미있는 단어 찾기

# %%
# train['Name'] 카테고리화
# Mr 0/ Miss 1 / Mrs 2 / Other 3  ...

# %%
# train['Name']

# %% [raw]
# # train, test 그룹화해서 Name 컬럼에서 특정 단어
# # (Mr. / Miss / Mrs...)
# # 추출  후 Title 컬럼에 삽입
# train_test_data = [train, test]
# for dataset in train_test_data:
#     dataset['Title'] = dataset['Name'].str.extract('
#                         ([A-Za-z]+)\.',  expand=False)

# %%
# 
train_test_data = [train, test] 
for dataset in train_test_data:
    dataset['Title'] = dataset['Name'].str.extract(' ([A-Za-z]+)\.', 
                                                   expand=False)

# %%
# train.head(3)
test.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked Title
# 0      0  330911  7.8292   NaN        Q    Mr
# 1      0  363272  7.0000   NaN        S   Mrs
# 2      0  240276  9.6875   NaN        Q    Mr

# %%
train['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Col           2
# Major         2
# Mlle          2
# Sir           1
# Mme           1
# Jonkheer      1
# Countess      1
# Capt          1
# Ms            1
# Lady          1
# Don           1
# Name: Title, dtype: int64

# %%
test['Title'].value_counts()
# Out:
# Mr        240
# Miss       78
# Mrs        72
# Master     21
# Rev         2
# Col         2
# Dr          1
# Dona        1
# Ms          1
# Name: Title, dtype: int64

# %% [markdown]
# #### 숫자로 분류시키기 (Title map) => title 컬럼
# Mr : 0
# Miss : 1
# Mrs: 2
# Others: 3

# %% [raw]
# title_mapping = {"Mr": 0, "Miss": 1, "Mrs": 2,
#                  "Master": 3, "Dr": 3, "Rev": 3,
#                  "Col": 3, "Major": 3,
#                  "Mlle": 3,"Countess": 3,
#                  "Ms": 3, "Lady": 3, "Jonkheer": 3, "Don": 3, "Dona" : 3, "Mme": 3,"Capt": 3,"Sir": 3 }
#
# for dataset in train_test_data:
#     dataset['Title'] =
#                dataset['Title'].map(title_mapping)
#
# train['Title'].value_counts()
# test['Title'].value_counts()

# %%
title_mapping = {"Mr": 0, "Miss": 1, "Mrs": 2, 
                 "Master": 3, "Dr": 3, "Rev": 3, "Col": 3, "Major": 3, "Mlle": 3,"Countess": 3,
                 "Ms": 1, "Lady": 1, "Jonkheer": 3, "Don": 0, "Dona" : 1, "Mme": 2,"Capt": 3,"Sir": 0 }
for dataset in train_test_data:
    dataset['Title'] = dataset['Title'].map(title_mapping)

# %%
train['Title'].value_counts()
test['Title'].value_counts()
# Out:
# 0    240
# 1     80
# 2     72
# 3     26
# Name: Title, dtype: int64

# %%
# Title 컬럼값 확인
train.info(),
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Sex            891 non-null int64
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       891 non-null int64
# Title          891 non-null int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 83.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Sex            418 non-null int64
# Age            418 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null int64
# Title          418 non-null int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 36.0+ KB

# %%
test.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked  Title
# 0      0  330911  7.8292   NaN        Q      0
# 1      0  363272  7.0000   NaN        S      2
# 2      0  240276  9.6875   NaN        Q      0

# %%
bar_chart('Title')

# %%
# Name 컬럼 삭제
train.drop('Name', axis=1, inplace=True)
test.drop('Name', axis=1, inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Title
# 0         A/5 21171   7.2500   NaN        S      0
# 1          PC 17599  71.2833   C85        C      2
# 2  STON/O2. 3101282   7.9250   NaN        S      1
# 3            113803  53.1000  C123        S      2
# 4            373450   8.0500   NaN        S      0

# %%
test.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch   Ticket     Fare Cabin  \
# 0          892       3    male  34.5      0      0   330911   7.8292   NaN
# 1          893       3  female  47.0      1      0   363272   7.0000   NaN
# 2          894       2    male  62.0      0      0   240276   9.6875   NaN
# 3          895       3    male  27.0      0      0   315154   8.6625   NaN
# 4          896       3  female  22.0      1      1  3101298  12.2875   NaN
#
#   Embarked  Title
# 0        Q      0
# 1        S      2
# 2        Q      0
# 3        S      0
# 4        S      2

# %% [markdown]
# ### Sex 전처리
#
# male: 0
# female: 1

# %%
sex_mapping = {"male": 0, "female": 1}
for dataset in train_test_data:
    dataset['Sex'] = dataset['Sex'].map(sex_mapping)

# %%
bar_chart('Sex')

# %% [markdown]
# ### Age 전처리
#
# - 누락값 NaN
# - 연속데이타를 카테고리화

# %%
train.head(100)
# Out:
#     PassengerId  Survived  Pclass  Sex    Age  SibSp  Parch            Ticket  \
# 0             1         0       3    0  22.00      1      0         A/5 21171
# 1             2         1       1    1  38.00      1      0          PC 17599
# 2             3         1       3    1  26.00      0      0  STON/O2. 3101282
# 3             4         1       1    1  35.00      1      0            113803
# 4             5         0       3    0  35.00      0      0            373450
# 5             6         0       3    0    NaN      0      0            330877
# 6             7         0       1    0  54.00      0      0             17463
# 7             8         0       3    0   2.00      3      1            349909
# 8             9         1       3    1  27.00      0      2            347742
# 9            10         1       2    1  14.00      1      0            237736
# 10           11         1       3    1   4.00      1      1           PP 9549
# 11           12         1       1    1  58.00      0      0            113783
# 12           13         0       3    0  20.00      0      0         A/5. 2151
# 13           14         0       3    0  39.00      1      5            347082
# 14           15         0       3    1  14.00      0      0            350406
# 15           16         1       2    1  55.00      0      0            248706
# 16           17         0       3    0   2.00      4      1            382652
# 17           18         1       2    0    NaN      0      0            244373
# 18           19         0       3    1  31.00      1      0            345763
# 19           20         1       3    1    NaN      0      0              2649
# 20           21         0       2    0  35.00      0      0            239865
# 21           22         1       2    0  34.00      0      0            248698
# 22           23         1       3    1  15.00      0      0            330923
# 23           24         1       1    0  28.00      0      0            113788
# 24           25         0       3    1   8.00      3      1            349909
# 25           26         1       3    1  38.00      1      5            347077
# 26           27         0       3    0    NaN      0      0              2631
# 27           28         0       1    0  19.00      3      2             19950
# 28           29         1       3    1    NaN      0      0            330959
# 29           30         0       3    0    NaN      0      0            349216
# ..          ...       ...     ...  ...    ...    ...    ...               ...
# 70           71         0       2    0  32.00      0      0        C.A. 33111
# 71           72         0       3    1  16.00      5      2           CA 2144
# 72           73         0       2    0  21.00      0      0      S.O.C. 14879
# 73           74         0       3    0  26.00      1      0              2680
# 74           75         1       3    0  32.00      0      0              1601
# 75           76         0       3    0  25.00      0      0            348123
# 76           77         0       3    0    NaN      0      0            349208
# 77           78         0       3    0    NaN      0      0            374746
# 78           79         1       2    0   0.83      0      2            248738
# 79           80         1       3    1  30.00      0      0            364516
# 80           81         0       3    0  22.00      0      0            345767
# 81           82         1       3    0  29.00      0      0            345779
# 82           83         1       3    1    NaN      0      0            330932
# 83           84         0       1    0  28.00      0      0            113059
# 84           85         1       2    1  17.00      0      0        SO/C 14885
# 85           86         1       3    1  33.00      3      0           3101278
# 86           87         0       3    0  16.00      1      3        W./C. 6608
# 87           88         0       3    0    NaN      0      0   SOTON/OQ 392086
# 88           89         1       1    1  23.00      3      2             19950
# 89           90         0       3    0  24.00      0      0            343275
# 90           91         0       3    0  29.00      0      0            343276
# 91           92         0       3    0  20.00      0      0            347466
# 92           93         0       1    0  46.00      1      0       W.E.P. 5734
# 93           94         0       3    0  26.00      1      2         C.A. 2315
# 94           95         0       3    0  59.00      0      0            364500
# 95           96         0       3    0    NaN      0      0            374910
# 96           97         0       1    0  71.00      0      0          PC 17754
# 97           98         1       1    0  23.00      0      1          PC 17759
# 98           99         1       2    1  34.00      0      1            231919
# 99          100         0       2    0  34.00      1      0            244367
#
#         Fare        Cabin Embarked  Title
# 0     7.2500          NaN        S      0
# 1    71.2833          C85        C      2
# 2     7.9250          NaN        S      1
# 3    53.1000         C123        S      2
# 4     8.0500          NaN        S      0
# 5     8.4583          NaN        Q      0
# 6    51.8625          E46        S      0
# 7    21.0750          NaN        S      3
# 8    11.1333          NaN        S      2
# 9    30.0708          NaN        C      2
# 10   16.7000           G6        S      1
# 11   26.5500         C103        S      1
# 12    8.0500          NaN        S      0
# 13   31.2750          NaN        S      0
# 14    7.8542          NaN        S      1
# 15   16.0000          NaN        S      2
# 16   29.1250          NaN        Q      3
# 17   13.0000          NaN        S      0
# 18   18.0000          NaN        S      2
# 19    7.2250          NaN        C      2
# 20   26.0000          NaN        S      0
# 21   13.0000          D56        S      0
# 22    8.0292          NaN        Q      1
# 23   35.5000           A6        S      0
# 24   21.0750          NaN        S      1
# 25   31.3875          NaN        S      2
# 26    7.2250          NaN        C      0
# 27  263.0000  C23 C25 C27        S      0
# 28    7.8792          NaN        Q      1
# 29    7.8958          NaN        S      0
# ..       ...          ...      ...    ...
# 70   10.5000          NaN        S      0
# 71   46.9000          NaN        S      1
# 72   73.5000          NaN        S      0
# 73   14.4542          NaN        C      0
# 74   56.4958          NaN        S      0
# 75    7.6500        F G73        S      0
# 76    7.8958          NaN        S      0
# 77    8.0500          NaN        S      0
# 78   29.0000          NaN        S      3
# 79   12.4750          NaN        S      1
# 80    9.0000          NaN        S      0
# 81    9.5000          NaN        S      0
# 82    7.7875          NaN        Q      1
# 83   47.1000          NaN        S      0
# 84   10.5000          NaN        S      1
# 85   15.8500          NaN        S      2
# 86   34.3750          NaN        S      0
# 87    8.0500          NaN        S      0
# 88  263.0000  C23 C25 C27        S      1
# 89    8.0500          NaN        S      0
# 90    8.0500          NaN        S      0
# 91    7.8542          NaN        S      0
# 92   61.1750          E31        S      0
# 93   20.5750          NaN        S      0
# 94    7.2500          NaN        S      0
# 95    8.0500          NaN        S      0
# 96   34.6542           A5        C      0
# 97   63.3583      D10 D12        C      0
# 98   23.0000          NaN        S      2
# 99   26.0000          NaN        S      0
#
# [100 rows x 12 columns]

# %%
# fill missing age with median age for each title (Mr, Mrs, Miss, Others)
train["Age"].fillna(train.groupby("Title")["Age"].transform("median"), inplace=True)
test["Age"].fillna(test.groupby("Title")["Age"].transform("median"), inplace=True)

# %%
# train.head(30)
# train.groupby("Title")["Age"].transform("median")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Sex            891 non-null int64
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# Title          891 non-null int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 83.6+ KB

# %% [markdown]
# ## Age & Survied  - FacetGrid 시각화

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()

plt.show()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    int64
#  4   Age          891 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
#  11  Title        891 non-null    int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 83.7+ KB

# %% [markdown]
# ## Age 카테고리화
#
# - 구간 분류 후 숫자값으로 채우기
# Binning/Converting Numerical Age to Categorical Variable
#
# feature vector map:
# child: 0
# young: 1
# adult: 2
# mid-age: 3
# senior: 4

# %%
for dataset in train_test_data:
    dataset.loc[dataset['Age'] <=16, 'Age'] = 0,
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 26), 'Age'] = 1,
    dataset.loc[(dataset['Age'] > 26) & (dataset['Age'] <= 36), 'Age'] = 2,
    dataset.loc[(dataset['Age'] > 36) & (dataset['Age'] <= 62), 'Age'] = 3,
    dataset.loc[dataset['Age'] > 62, 'Age'] =4

# %%
test[test['Age'] >0]
# Out:
#      PassengerId  Pclass  Sex  Age  SibSp  Parch              Ticket  \
# 0            892       3    0  2.0      0      0              330911
# 1            893       3    1  3.0      1      0              363272
# 2            894       2    0  3.0      0      0              240276
# 3            895       3    0  2.0      0      0              315154
# 4            896       3    1  1.0      1      1             3101298
# 6            898       3    1  2.0      0      0              330972
# 7            899       2    0  1.0      1      1              248738
# 8            900       3    1  1.0      0      0                2657
# 9            901       3    0  1.0      2      0           A/4 48871
# 10           902       3    0  2.0      0      0              349220
# 11           903       1    0  3.0      0      0                 694
# 12           904       1    1  1.0      1      0               21228
# 13           905       2    0  4.0      1      0               24065
# 14           906       1    1  3.0      1      0         W.E.P. 5734
# 15           907       2    1  1.0      1      0       SC/PARIS 2167
# 16           908       2    0  2.0      0      0              233734
# 17           909       3    0  1.0      0      0                2692
# 18           910       3    1  2.0      1      0    STON/O2. 3101270
# 19           911       3    1  3.0      0      0                2696
# 20           912       1    0  3.0      1      0            PC 17603
# 22           914       1    1  3.0      0      0            PC 17598
# 23           915       1    0  1.0      0      1            PC 17597
# 24           916       1    1  3.0      1      3            PC 17608
# 25           917       3    0  3.0      1      0           A/5. 3337
# 26           918       1    1  1.0      0      1              113509
# 27           919       3    0  1.0      0      0                2698
# 28           920       1    0  3.0      0      0              113054
# 29           921       3    0  2.0      2      0                2662
# 30           922       2    0  3.0      1      0          SC/AH 3085
# 31           923       2    0  1.0      2      0          C.A. 31029
# ..           ...     ...  ...  ...    ...    ...                 ...
# 384         1276       2    0  2.0      0      0       SC/PARIS 2159
# 385         1277       2    1  1.0      1      2              220845
# 386         1278       3    0  1.0      0      0              349911
# 387         1279       2    0  3.0      0      0              244346
# 388         1280       3    0  1.0      0      0              364858
# 390         1282       1    0  1.0      0      0               12749
# 391         1283       1    1  3.0      0      1            PC 17592
# 393         1285       2    0  3.0      0      0          C.A. 30769
# 394         1286       3    0  2.0      3      1              315153
# 395         1287       1    1  1.0      1      0               13695
# 396         1288       3    0  1.0      0      0              371109
# 397         1289       1    1  3.0      1      1               13567
# 398         1290       3    0  1.0      0      0              347065
# 399         1291       3    0  2.0      0      0               21332
# 400         1292       1    1  2.0      0      0               36928
# 401         1293       2    0  3.0      1      0               28664
# 402         1294       1    1  1.0      0      1              112378
# 403         1295       1    0  1.0      0      0              113059
# 404         1296       1    0  3.0      1      0               17765
# 405         1297       2    0  1.0      0      0       SC/PARIS 2166
# 406         1298       2    0  1.0      1      0               28666
# 407         1299       1    0  3.0      1      1              113503
# 408         1300       3    1  1.0      0      0              334915
# 410         1302       3    1  1.0      0      0              365237
# 411         1303       1    1  3.0      1      0               19928
# 412         1304       3    1  2.0      0      0              347086
# 413         1305       3    0  2.0      0      0           A.5. 3236
# 414         1306       1    1  3.0      0      0            PC 17758
# 415         1307       3    0  3.0      0      0  SOTON/O.Q. 3101262
# 416         1308       3    0  2.0      0      0              359309
#
#          Fare            Cabin Embarked  Title
# 0      7.8292              NaN        Q      0
# 1      7.0000              NaN        S      2
# 2      9.6875              NaN        Q      0
# 3      8.6625              NaN        S      0
# 4     12.2875              NaN        S      2
# 6      7.6292              NaN        Q      1
# 7     29.0000              NaN        S      0
# 8      7.2292              NaN        C      2
# 9     24.1500              NaN        S      0
# 10     7.8958              NaN        S      0
# 11    26.0000              NaN        S      0
# 12    82.2667              B45        S      2
# 13    26.0000              NaN        S      0
# 14    61.1750              E31        S      2
# 15    27.7208              NaN        C      2
# 16    12.3500              NaN        Q      0
# 17     7.2250              NaN        C      0
# 18     7.9250              NaN        S      1
# 19     7.2250              NaN        C      2
# 20    59.4000              NaN        C      0
# 22    31.6833              NaN        S      2
# 23    61.3792              NaN        C      0
# 24   262.3750  B57 B59 B63 B66        C      2
# 25    14.5000              NaN        S      0
# 26    61.9792              B36        C      1
# 27     7.2250              NaN        C      0
# 28    30.5000              A21        S      0
# 29    21.6792              NaN        C      0
# 30    26.0000              NaN        S      0
# 31    31.5000              NaN        S      0
# ..        ...              ...      ...    ...
# 384   12.8750              NaN        S      0
# 385   65.0000              NaN        S      1
# 386    7.7750              NaN        S      0
# 387   13.0000              NaN        S      0
# 388    7.7500              NaN        Q      0
# 390   93.5000              B24        S      0
# 391   39.4000              D28        S      2
# 393   10.5000              NaN        S      0
# 394   22.0250              NaN        S      0
# 395   60.0000              C31        S      2
# 396    7.2500              NaN        Q      0
# 397   79.2000              B41        C      2
# 398    7.7750              NaN        S      0
# 399    7.7333              NaN        Q      0
# 400  164.8667               C7        S      1
# 401   21.0000              NaN        S      0
# 402   59.4000              NaN        C      1
# 403   47.1000              NaN        S      0
# 404   27.7208              D40        C      0
# 405   13.8625              D38        C      0
# 406   10.5000              NaN        S      0
# 407  211.5000              C80        C      0
# 408    7.7208              NaN        Q      1
# 410    7.7500              NaN        Q      1
# 411   90.0000              C78        Q      2
# 412    7.7750              NaN        S      1
# 413    8.0500              NaN        S      0
# 414  108.9000             C105        C      1
# 415    7.2500              NaN        S      0
# 416    8.0500              NaN        S      0
#
# [380 rows x 11 columns]

# %%
bar_chart('Age')

# %%
Pclass1 = train[train['Pclass']==1]['Embarked'].value_counts()
Pclass2 = train[train['Pclass']==2]['Embarked'].value_counts()
Pclass3 = train[train['Pclass']==3]['Embarked'].value_counts()
print(Pclass1,Pclass2,Pclass3)
# Out:
# S    127
# C     85
# Q      2
# Name: Embarked, dtype: int64 S    164
# C     17
# Q      3
# Name: Embarked, dtype: int64 S    353
# Q     72
# C     66
# Name: Embarked, dtype: int64

# %%
df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class','2nd class','3rd class']
df
# Out:
#              S   C   Q
# 1st class  127  85   2
# 2nd class  164  17   3
# 3rd class  353  66  72

# %%
df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].fillna('S')

# %%
embarked_mapping = {"S":0,"C":1,"Q":2}
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].map(embarked_mapping)

# %%
test['Fare'].isnull().sum()
# Out:
# 1

# %%
test["Fare"].fillna(test['Fare'].mean())
# Out:
# 0        7.8292
# 1        7.0000
# 2        9.6875
# 3        8.6625
# 4       12.2875
# 5        9.2250
# 6        7.6292
# 7       29.0000
# 8        7.2292
# 9       24.1500
# 10       7.8958
# 11      26.0000
# 12      82.2667
# 13      26.0000
# 14      61.1750
# 15      27.7208
# 16      12.3500
# 17       7.2250
# 18       7.9250
# 19       7.2250
# 20      59.4000
# 21       3.1708
# 22      31.6833
# 23      61.3792
# 24     262.3750
# 25      14.5000
# 26      61.9792
# 27       7.2250
# 28      30.5000
# 29      21.6792
#          ...
# 388      7.7500
# 389     21.0750
# 390     93.5000
# 391     39.4000
# 392     20.2500
# 393     10.5000
# 394     22.0250
# 395     60.0000
# 396      7.2500
# 397     79.2000
# 398      7.7750
# 399      7.7333
# 400    164.8667
# 401     21.0000
# 402     59.4000
# 403     47.1000
# 404     27.7208
# 405     13.8625
# 406     10.5000
# 407    211.5000
# 408      7.7208
# 409     13.7750
# 410      7.7500
# 411     90.0000
# 412      7.7750
# 413      8.0500
# 414    108.9000
# 415      7.2500
# 416      8.0500
# 417     22.3583
# Name: Fare, Length: 418, dtype: float64

# %%
for dataset in train_test_data:
    dataset['Cabin'] = dataset['Cabin'].str[:1]

# %%
Pclass1 = train[train['Pclass']==1]['Cabin'].value_counts()
Pclass2 = train[train['Pclass']==2]['Cabin'].value_counts()
Pclass3 = train[train['Pclass']==3]['Cabin'].value_counts()
df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class','2nd class', '3rd class']
df
# Out:
#               C     B     D     E     A    T    F    G
# 1st class  59.0  47.0  29.0  25.0  15.0  1.0  NaN  NaN
# 2nd class   NaN   NaN   4.0   4.0   NaN  NaN  8.0  NaN
# 3rd class   NaN   NaN   NaN   3.0   NaN  NaN  5.0  4.0

# %%
cabin_mapping = {"A": 0, "B": 0.4, "C": 0.8, "D": 1.2, "E": 1.6, "F": 2, "G": 2.4, "T": 2.8}
for dataset in train_test_data:
    dataset['Cabin'] = dataset['Cabin'].map(cabin_mapping)

# %%
# Pclass의 중간값으로 
train["Cabin"].fillna(train.groupby("Pclass")["Cabin"].transform("median"), inplace=True)
test["Cabin"].fillna(test.groupby("Pclass")["Cabin"].transform("median"), inplace=True)

# %%
train["Cabin"].value_counts()
# Out:
# 2.0    492
# 1.8    168
# 0.8     99
# 0.4     47
# 1.2     33
# 1.6     32
# 0.0     15
# 2.4      4
# 2.8      1
# Name: Cabin, dtype: int64

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Sex            418 non-null int64
# Age            418 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           418 non-null float64
# Cabin          418 non-null float64
# Embarked       418 non-null int64
# Title          418 non-null int64
# dtypes: float64(3), int64(7), object(1)
# memory usage: 36.0+ KB

# %%
train["Fare"].fillna(train.groupby("Pclass")["Fare"].transform("median"), inplace=True)
test["Fare"].fillna(test.groupby("Pclass")["Fare"].transform("median"), inplace=True)

# %%
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
test["FamilySize"] = test["SibSp"] + test["Parch"] + 1

# %%
features_drop = ['Ticket', 'SibSp', 'Parch']
train = train.drop(features_drop, axis=1)
test = test.drop(features_drop, axis=1)
train = train.drop(['PassengerId'], axis=1)

# %%
train_data = train.drop('Survived', axis=1)
# Survived 만 별도 시리즈로 저장
target = train['Survived']

train_data.shape, target.shape
# Out:
# ((891, 8), (891,))

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

import numpy as np

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# 10개로 나누 경우 
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
clf = KNeighborsClassifier(n_neighbors = 13)
# scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, 
                        cv=k_fold, n_jobs=1, scoring='accuracy')
score
# Out:
# array([0.75555556, 0.75280899, 0.76404494, 0.71910112, 0.78651685,
#        0.75280899, 0.7752809 , 0.74157303, 0.75280899, 0.79775281])

# %%
# kNN Score
round(np.mean(score)*100, 2)
# Out:
# 75.98

# %%
clf = SVC()
score = cross_val_score(clf, train_data, target, cv=k_fold, 
                        n_jobs=1, scoring='accuracy')
print(score)
# Out:
# [0.75555556 0.82022472 0.79775281 0.76404494 0.79775281 0.7752809
#  0.82022472 0.80898876 0.76404494 0.83146067]

# %%
round(np.mean(score)*100,2)
# Out:
# 79.35

# %%
clf = RandomForestClassifier(n_estimators=13)

score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, 
                        scoring='accuracy')
score
# Out:
# array([0.74444444, 0.82022472, 0.82022472, 0.82022472, 0.84269663,
#        0.78651685, 0.80898876, 0.80898876, 0.7752809 , 0.79775281])

# %%
# Random Forest Score
round(np.mean(score)*100, 2)
# Out:
# 80.25

# %%
# 모델링
clf = RandomForestClassifier(n_estimators=13)
clf.fit(train_data, target)

# 검증
test_data = test.drop("PassengerId", axis=1).copy()
prediction = clf.predict(test_data)

# %%
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": prediction
    })

submission.to_csv('submission.csv', index=False)

# %%
submission = pd.read_csv('submission.csv')
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1
